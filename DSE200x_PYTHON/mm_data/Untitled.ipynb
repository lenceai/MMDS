# %% [markdown]
# # Import the needed packages

# %%
import numpy as np
import pandas as pd
import matplotlib as plt
# %matplotlib inline

# %%
df = pd.read_csv('flaredown-autoimmune-symptom-tracker/fd-export.csv', low_memory=False)
df.shape
# Out:
# (3487633, 9)

# %% [markdown]
# # Filter for Crohn's

# %%
df = df[df['trackable_name'] == "Crohn's disease"]
del df['age']
del df['sex']
del df['country']

# %%
df['user_id'] = pd.Categorical(df['user_id'])
df['user_id'] = df.user_id.cat.codes

# %%
df.head(3000)
# Out:
#                                user_id   age     sex country checkin_date  \
# 0     QEVuQwEABlEzkh7fsBBjEe26RyIVcg==   NaN     NaN     NaN   2015-11-26
# 1     QEVuQwEAWRNGnuTRqXG2996KSkTIEw==  31.0    male      US   2015-11-26
# 2     QEVuQwEA+WkNxtp/qkHvN2YmTBBDqg==   1.0  female      CA   2017-04-28
# 3     QEVuQwEA+WkNxtp/qkHvN2YmTBBDqg==   1.0  female      CA   2017-04-28
# 4     QEVuQwEA+WkNxtp/qkHvN2YmTBBDqg==   1.0  female      CA   2017-04-28
# 5     QEVuQwEA+WkNxtp/qkHvN2YmTBBDqg==   1.0  female      CA   2017-04-28
# 6     QEVuQwEA+WkNxtp/qkHvN2YmTBBDqg==   1.0  female      CA   2017-04-28
# 7     QEVuQwEA+WkNxtp/qkHvN2YmTBBDqg==   1.0  female      CA   2017-04-28
# 8     QEVuQwEA+WkNxtp/qkHvN2YmTBBDqg==   1.0  female      CA   2017-04-28
# 9     QEVuQwEA+WkNxtp/qkHvN2YmTBBDqg==   1.0  female      CA   2017-04-28
# 10    QEVuQwEA+WkNxtp/qkHvN2YmTBBDqg==   1.0  female      CA   2017-04-28
# 11    QEVuQwEA+WkNxtp/qkHvN2YmTBBDqg==   1.0  female      CA   2017-04-28
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3591 entries, 22 to 3475450
# Data columns (total 6 columns):
# user_id            3591 non-null object
# checkin_date       3591 non-null object
# trackable_id       3591 non-null object
# trackable_type     3591 non-null object
# trackable_name     3591 non-null object
# trackable_value    3591 non-null object
# dtypes: object(6)
# memory usage: 196.4+ KB

# %%
df.nunique()
# Out:
# user_id            619
# checkin_date       938
# trackable_id         2
# trackable_type       2
# trackable_name       1
# trackable_value      5
# dtype: int64

# %%
df['user_id'] = pd.Categorical(df['user_id'])
df['user_id'] = df.user_id.cat.codes

# %% [markdown]
# # Filter for Crohn's

# %%
df = df[df['trackable_name'] == "Crohn's disease"]
del df['age']
del df['sex']
del df['country']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# D:\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2655             try:
# -> 2656                 return self._engine.get_loc(key)
#    2657             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'age'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-36-270619526384> in <module>
# ...

# %%
df.head()
# Out:
#      user_id         sex country checkin_date trackable_id trackable_type  \
# 22      6771         NaN     NaN   2015-06-22          269      Condition
# 191     5532      female      US   2015-06-22          269      Condition
# 411    15541  doesnt_say      SE   2016-06-15          269      Condition
# 420    15541  doesnt_say      SE   2016-07-06          269      Condition
# 767    15531      female      CA   2015-06-25          269      Condition
#
#       trackable_name trackable_value
# 22   Crohn's disease               3
# 191  Crohn's disease               3
# 411  Crohn's disease               3
# 420  Crohn's disease               3
# 767  Crohn's disease               0
