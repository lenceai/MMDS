# %%
import numpy as np
import pandas as pd

# %%
# !dir "world-development-indicators"
# Out:
#  Volume in drive D is work_files
#  Volume Serial Number is A2F5-5387
#
#  Directory of D:\files\OneDrive\MMDS\DSE200x_python_for_ds\Week-6-Mini\world-development-indicators
#
# 02/25/2019  12:03 PM    <DIR>          .
# 02/25/2019  12:03 PM    <DIR>          ..
# 05/01/2017  10:00 AM           131,845 Country.csv
# 05/01/2017  10:00 AM           655,490 CountryNotes.csv
# 05/01/2017  10:00 AM     1,411,481,600 database.sqlite
# 05/01/2017  10:00 AM        52,390,816 Footnotes.csv
# 05/01/2017  10:00 AM             1,031 hashes.txt
# 05/01/2017  10:00 AM       574,305,253 Indicators.csv
# 05/01/2017  10:00 AM         3,309,006 Series.csv
# 05/01/2017  10:00 AM            32,782 SeriesNotes.csv
#                8 File(s)  2,042,307,823 bytes
#                2 Dir(s)  839,222,951,936 bytes free

# %%
country = pd.read_csv('./world-development-indicators/Country.csv')
notes = pd.read_csv('./world-development-indicators/CountryNotes.csv')
footnotes = pd.read_csv('./world-development-indicators/Footnotes.csv')
indicators = pd.read_csv('./world-development-indicators/Indicators.csv')
series = pd.read_csv('./world-development-indicators/Series.csv')
seriesnotes = pd.read_csv('./world-development-indicators/SeriesNotes.csv')

# %%
country.head(1)
# Out:
#   CountryCode    ShortName    TableName                      LongName  \
# 0         AFG  Afghanistan  Afghanistan  Islamic State of Afghanistan
#
#   Alpha2Code    CurrencyUnit  \
# 0         AF  Afghan afghani
#
#                                         SpecialNotes      Region IncomeGroup  \
# 0  Fiscal year end: March 20; reporting period fo...  South Asia  Low income
#
#   Wb2Code            ...                 GovernmentAccountingConcept  \
# 0      AF            ...             Consolidated central government
#
#                ImfDataDisseminationStandard LatestPopulationCensus  \
# 0  General Data Dissemination System (GDDS)                   1979
#
#                                LatestHouseholdSurvey  \
# 0  Multiple Indicator Cluster Survey (MICS), 2010/11
#
#   SourceOfMostRecentIncomeAndExpenditureData VitalRegistrationComplete  \
# 0    Integrated household survey (IHS), 2008                       NaN
#
# ...

# %%
notes.head(1)
# Out:
#   Countrycode         Seriescode  \
# 0         ABW  EG.EGY.PRIM.PP.KD
#
#                                          Description
# 0  Sources: Estimated based on UN Energy Statisti...

# %%
footnotes.head(1)
# Out:
#   Countrycode      Seriescode    Year    Description
# 0         ABW  AG.LND.FRST.K2  YR1990  Not specified

# %%
indicators.head(10)
# Out:
#   CountryName CountryCode                                      IndicatorName  \
# 0  Arab World         ARB  Adolescent fertility rate (births per 1,000 wo...
# 1  Arab World         ARB  Age dependency ratio (% of working-age populat...
# 2  Arab World         ARB  Age dependency ratio, old (% of working-age po...
# 3  Arab World         ARB  Age dependency ratio, young (% of working-age ...
# 4  Arab World         ARB        Arms exports (SIPRI trend indicator values)
# 5  Arab World         ARB        Arms imports (SIPRI trend indicator values)
# 6  Arab World         ARB               Birth rate, crude (per 1,000 people)
# 7  Arab World         ARB                                 CO2 emissions (kt)
# 8  Arab World         ARB             CO2 emissions (metric tons per capita)
# 9  Arab World         ARB  CO2 emissions from gaseous fuel consumption (%...
#
#        IndicatorCode  Year         Value
# 0        SP.ADO.TFRT  1960  1.335609e+02
# ...

# %%
series.head(1)
# Out:
#        SeriesCode                                              Topic  \
# 0  BN.KLT.DINV.CD  Economic Policy & Debt: Balance of payments: C...
#
#                                        IndicatorName ShortDefinition  \
# 0  Foreign direct investment, net (BoP, current US$)             NaN
#
#                                       LongDefinition UnitOfMeasure  \
# 0  Foreign direct investment are the net inflows ...           NaN
#
#   Periodicity BasePeriod  OtherNotes AggregationMethod  \
# 0      Annual        NaN         NaN               NaN
#
#   LimitationsAndExceptions NotesFromOriginalSource  \
# 0                      NaN                     NaN
#
#                                      GeneralComments  \
# 0  Note: Data are based on the sixth edition of t...
#
#                                               Source  \
# 0  International Monetary Fund, Balance of Paymen...
#
#   StatisticalConceptAndMethodology DevelopmentRelevance RelatedSourceLinks  \
# ...

# %%
seriesnotes.head(1)
# Out:
#     Seriescode    Year                                 Description
# 0  SP.ADO.TFRT  YR1960  Interpolated using data for 1957 and 1962.
